# %% [markdown]
# # 파이썬 기초 종합 테스트
# > ipynb 파일 제출처: serendipi27@gmail.com
# - 제출 시간을 엄수해 주세요.

# %% [markdown]
# # part1. 객관식 10문제
# > 다음 문제를 읽고, 문제 아래 Text Cell에 정답을 작성하세요.

# %% [markdown]
# 파이썬 시험친 김민규입니다

# %% [markdown]
# ## 문제1) 다음 중 파이썬의 자료형이 아닌 것은?
# - a) int
# - b) str
# - c) list
# - d) array

# %% [markdown]
# 정답:

# %%
d

# %% [markdown]
# ## 문제2) 다음 중 파이썬에서 주석을 작성하는 방법은?
# - a) //
# - b) #
# - c) /*
# - d) **

# %% [markdown]
# 정답:

# %%
b

# %% [markdown]
# ## 문제3) 파이썬에서 문자열을 연결하는 연산자는?
# - a) &
# - b) +
# - c) *
# - d) %

# %% [markdown]
# 정답:

# %%
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 s="sum"
#       2 d ="sum"
# ----> 4 s & d
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %% [markdown]
# ## 문제4) 리스트 ll = [1, 2, 3]에 요소 4를 추가하는 방법은?
# - a) ll.add(4)
# - b) ll.append(4)
# - c) ll.insert(4)
# - d) ll.extend(4)

# %% [markdown]
# 정답:

# %%
b

# %% [markdown]
# ## 문제5) 다음 중 올바른 변수명은?
# - a) 1st_number
# - b) number-1
# - c) first_number
# - d) number.1

# %% [markdown]
# 정답:

# %%
c

# %% [markdown]
# ## 문제6) 파이썬에서 반복문을 사용하는 키워드는?
# - a) loop
# - b) repeat
# - c) for
# - d) foreach

# %% [markdown]
# 정답:

# %%
c

# %% [markdown]
# ## 문제7) 파이썬에서 조건문을 사용하는 키워드는?
# - a) if
# - b) switch
# - c) else if
# - d) when

# %% [markdown]
# 정답:

# %%
a

# %% [markdown]
# ## 문제8) 다음 코드의 출력 결과는? print("Hello" * 3)
# - a) HelloHelloHello
# - b) Hello Hello Hello
# - c) Hello3
# - d) SyntaxError

# %% [markdown]
# 정답:

# %%
a
# Out:
# HelloHelloHello

# %% [markdown]
# ## 문제9) 다음 코드의 출력 결과는? print(10 // 3)
# - a) 3.3333
# - b) 3
# - c) 4
# - d) 3.0

# %% [markdown]
# 정답:

# %%
b
# Out:
# 3

# %% [markdown]
# ## 문제10) 리스트 ll = [1, 2, 3, 4, 5]의 첫 번째 요소를 제거하는 방법은?
# - a) ll.remove(0)
# - b) ll.pop(1)
# - c) ll.pop(0)
# - d) ll.delete(0)

# %% [markdown]
# 정답:

# %%
c
# Out:
# 1

# %% [markdown]
# # part2. 코딩 10문제
# > 다음 문제를 읽고, 문제 아래 Code Cell에 코드를 작성하세요.
# - 반드시 문제에서 요구하는 사항이 모두 반영되어야 함.
# - 그 외 추가적인 코드는 포함되어도 상관없음.
# - 함수를 작성하고, 함수를 테스트하는 코드를 반드시 포함할 것.

# %% [markdown]
# ## 문제1) 정수를 입력받아 그 수가 짝수인지 홀수인지 판단하는 함수를 작성하세요.

# %%
number = int(input("정수입력해주세요"))

if number % 2 == 0:
    print("짝수입니다")
else:
    print("홀수입니다")
# Out:
# 홀수입니다

# %% [markdown]
# ## 문제2) 문자열을 입력받아 그 문자열을 거꾸로 출력하는 함수를 작성하세요.

# %%
sting = "abcd"
sting_1=sting.replace("abc","cba")
print(sting_1)
# Out:
# cbad

# %% [markdown]
# ## 문제3) 주어진 리스트의 요소 중 최대값을 반환하는 함수를 작성하세요.

# %%
number = [1,2,3]


num = max(number)
print(num)
# Out:
# 3

# %% [markdown]
# ## 문제4) 주어진 리스트에서 중복을 제거한 새 리스트를 반환하는 함수를 작성하세요.

# %%
number = (1,2,1,2)

number_1 = list(set(number))
print(number_1)
# Out:
# [1, 2]

# %% [markdown]
# ## 문제5) 문자열에서 모음의 개수를 세는 함수를 작성하세요.

# %%
string = 'asbasbf'
count = 0
for i in string:
    if i in ['a']:
        count += 1
print(count)
# Out:
# 2

# %% [markdown]
# ## 문제6) 리스트에서 홀수만을 반환하는 함수를 작성하세요.

# %%
number = [1,2,3,4,5]

for i in number:
    if (i % 2 == 1):
        print(i)
# Out:
# 1
# 3
# 5

# %% [markdown]
# ## 문제7) 적어도 3개 이상의 단어로 구성된 문자열에서 각 단어의 첫 글자만 대문자로 변환하는 함수를 작성하세요.

# %%
def string(string_1):
    string_1 = string.upper
    


string_1 = ["apple","number","sum"]
print(string(string_1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 6
#       2     return string.upper(string_1)
#       5 string_1 = ["apple","number","sum"]
# ----> 6 print(string(string_1))
#
# Cell In[96], line 2, in string(string_1)
#       1 def string(string_1):
# ----> 2     return string.upper(string_1)
#
# AttributeError: 'function' object has no attribute 'upper'

# %% [markdown]
# ## 문제8) 리스트 ll=['tiger', 'rabbit', 'cat', 'dog', 'tiger', 'lion', 'cat', 'tiger']에서, 특정 값의 모든 인덱스를 찾는 함수를 작성하세요. 입력 인자는 ll과 ll 안의 특정 요소 값임.
# - ex) 'tiger'의 인덱스는 0, 4, 7임.

# %%
def 

ll=['tiger', 'rabbit', 'cat', 'dog', 'tiger', 'lion', 'cat', 'tiger']
